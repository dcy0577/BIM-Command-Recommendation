# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## Read data from support calculation of high-\low-level command pairs

# %%
path = '/data/support.parquet'

# %%
df = pd.read_parquet (path)
df
# Out:
#                                              tuple_commands  \
# 0         [Tool: Text (-200), End Event: Modify Text (282)]
# 1                 [Tool: Text (-200), End Event: Drag (75)]
# 2         [Tool: Text (-200), End Event: Set Active Laye...
# 3            [Menu: Save -  (-5) (0), End Event: Drag (75)]
# 4         [Menu: Save -  (-5) (0), End Event: Set Active...
# ...                                                     ...
# 10611517  [Menu: Create Section Viewport -  (-114) (0), ...
# 10611518  [Menu: Force Select -  (-346) (0), End Event: ...
# 10611519  [Menu: Change Plant Grouping -  (350) (0), End...
# 10611520  [Menu: Change Plant Grouping -  (350) (0), End...
# 10611521  [Tool: Detail Cut Wood (-231), End Event: Upda...
#
#                                             tool/menu  \
# 0                                   Tool: Text (-200)
# 1                                   Tool: Text (-200)
# 2                                   Tool: Text (-200)
# 3                              Menu: Save -  (-5) (0)
# 4                              Menu: Save -  (-5) (0)
# ...                                               ...
# 10611517  Menu: Create Section Viewport -  (-114) (0)
# 10611518             Menu: Force Select -  (-346) (0)
# 10611519     Menu: Change Plant Grouping -  (350) (0)
# 10611520     Menu: Change Plant Grouping -  (350) (0)
# 10611521                 Tool: Detail Cut Wood (-231)
#
#                                               event  sup1  sup2  file_index
# 0                      End Event: Modify Text (282)     3     1           0
# 1                              End Event: Drag (75)     3     2           0
# 2                  End Event: Set Active Layer (32)     3     1           0
# 3                              End Event: Drag (75)    87    37           0
# 4                  End Event: Set Active Layer (32)    87    23           0
# ...                                             ...   ...   ...         ...
# 10611517           End Event: Create PolyLine (231)   748     2         155
# 10611518  End Event: Edit Record in Worksheet (349)  7488     2         155
# 10611519             End Event: Plug-in Event (166)     2     1         155
# 10611520                   End Event: Reshape (279)     2     1         155
# 10611521         End Event: Update References (128)    22     1         155
#
# [10611522 rows x 6 columns]

# %% [markdown]
# ## Alignment of sub-files' calculation.

# %%
# As the support calculation is done by calculating sub-files, this step is to merge sup1 and sup2 together
def process_data(df_sorted):
    processed_data = []
    grouped_df = df_sorted.groupby('tool/menu')

    # Calculate sup1_group_sum for each tool/menu group
    for group_name, group_df in tqdm(grouped_df, desc='processing merging'):
        # Calculate sup1_group_sum for the current group
        sup1_group_sum = group_df.drop_duplicates('file_index')['sup1'].sum()
        
        # Assign sup1_group_sum to all rows in the current group
        group_df['sup1_group_sum'] = sup1_group_sum

        # Calculate sup2_sum for each event within the current group
        event_sums = group_df.groupby('event')['sup2'].sum().rename('sup2_sum')
        
        # Map sup2_sum back to the original group_df
        group_df = group_df.join(event_sums, on='event')

        processed_data.append(group_df)

    # Combine all processed groups back into a single DataFrame
    result_df = pd.concat(processed_data, ignore_index=True)
    return result_df

# %%
df_sum = process_data(df)
# Out:
# processing merging: 100%|█████████████████| 9155/9155 [00:05<00:00, 1547.01it/s]

# %%
df_sum
# Out:
#                                              tuple_commands  \
# 0         [Menu:  -  (201) (0), End Event: Set Units (148)]
# 1         [Menu:  -  (201) (0), End Event: Create linear...
# 2             [Menu:  -  (201) (0), End Event: Delete (58)]
# 3               [Menu:  -  (201) (0), End Event: Drag (75)]
# 4         [Menu:  -  (201) (0), End Event: Plug-in Event...
# ...                                                     ...
# 10611517  [Tool: ~ScaleMaker V2 (-232), End Event: Delet...
# 10611518  [Tool: ~ScaleMaker V2 (-232), End Event: Chang...
# 10611519  [Tool: ~ScaleMaker V2 (-232), End Event: Resiz...
# 10611520  [Tool: ~ScaleMaker V2 (-232), End Event: Mirro...
# 10611521  [Tool: ~ScaleMaker V2 (-232), End Event: Creat...
#
#                             tool/menu  \
# 0                 Menu:  -  (201) (0)
# 1                 Menu:  -  (201) (0)
# 2                 Menu:  -  (201) (0)
# 3                 Menu:  -  (201) (0)
# 4                 Menu:  -  (201) (0)
# ...                               ...
# 10611517  Tool: ~ScaleMaker V2 (-232)
# 10611518  Tool: ~ScaleMaker V2 (-232)
# 10611519  Tool: ~ScaleMaker V2 (-232)
# 10611520  Tool: ~ScaleMaker V2 (-232)
# 10611521  Tool: ~ScaleMaker V2 (-232)
#
#                                             event  sup1  sup2  file_index  \
# 0                      End Event: Set Units (148)     1     1           1
# 1         End Event: Create linear dimension (23)     1     1           1
# 2                          End Event: Delete (58)     1     1           1
# 3                            End Event: Drag (75)     1     1           1
# 4                  End Event: Plug-in Event (166)     1     1           3
# ...                                           ...   ...   ...         ...
# 10611517                   End Event: Delete (58)     8     4         135
# 10611518        End Event: Change Attributes (11)     8     1         135
# 10611519                  End Event: Resize (146)     8     1         135
# 10611520         End Event: Mirror Duplicate (86)     8     1         135
# 10611521             End Event: Create Line (166)     8     2         135
#
#           sup1_group_sum  sup2_sum
# 0                     84        27
# 1                     84         2
# 2                     84        11
# 3                     84         8
# 4                     84        16
# ...                  ...       ...
# 10611517              21         5
# 10611518              21         1
# 10611519              21         2
# 10611520              21         5
# 10611521              21         3
#
# [10611522 rows x 8 columns]

# %% [markdown]
# ## Calculate Confidence

# %%
df_sum_1 = df_sum.sort_values(by= ['sup1_group_sum', 'sup2_sum'], ascending = False)
df_sum_2 = df_sum_1.drop(columns = ['sup1','sup2','file_index'])

# %%
df_sum_2['confidence'] = df_sum_2['sup2_sum']/df_sum_2['sup1_group_sum']

# %%
df_sum_2
# Out:
#                                             tuple_commands  \
# 9574073   [Tool: Reshape (-214), End Event: Reshape (279)]
# 9574577   [Tool: Reshape (-214), End Event: Reshape (279)]
# 9575104   [Tool: Reshape (-214), End Event: Reshape (279)]
# 9575617   [Tool: Reshape (-214), End Event: Reshape (279)]
# 9576138   [Tool: Reshape (-214), End Event: Reshape (279)]
# ...                                                    ...
# 7038370  [Menu: VWRemoteClientMenu - Vectorworks Remote...
# 7038371  [Menu: VWRemoteClientMenu - Vectorworks Remote...
# 6305154  [Menu: Shao Yi - (266) (0), End Event: The End...
# 6305155  [Menu: Shao Yi - (266) (0), End Event: Mirror ...
# 300444   [Menu: Automate Scale -  (310) (0), End Event:...
#
#                                                  tool/menu  \
# 9574073                               Tool: Reshape (-214)
# 9574577                               Tool: Reshape (-214)
# 9575104                               Tool: Reshape (-214)
# 9575617                               Tool: Reshape (-214)
# 9576138                               Tool: Reshape (-214)
# ...                                                    ...
# 7038370  Menu: VWRemoteClientMenu - Vectorworks Remote....
# 7038371  Menu: VWRemoteClientMenu - Vectorworks Remote....
# 6305154                          Menu: Shao Yi - (266) (0)
# 6305155                          Menu: Shao Yi - (266) (0)
# 300444                   Menu: Automate Scale -  (310) (0)
#
#                                       event  sup1_group_sum  sup2_sum  \
# 9574073            End Event: Reshape (279)        29945982  21260047
# 9574577            End Event: Reshape (279)        29945982  21260047
# 9575104            End Event: Reshape (279)        29945982  21260047
# 9575617            End Event: Reshape (279)        29945982  21260047
# 9576138            End Event: Reshape (279)        29945982  21260047
# ...                                     ...             ...       ...
# 7038370    End Event: Set Active Layer (59)               5         1
# 7038371      End Event: Plug-in Event (166)               5         1
# 6305154       End Event: The End Event (-1)               3         3
# 6305155    End Event: Mirror Duplicate (86)               3         3
# 300444   End Event: Update References (128)               1         1
#
#          confidence
# 9574073    0.709947
# 9574577    0.709947
# 9575104    0.709947
# 9575617    0.709947
# 9576138    0.709947
# ...             ...
# 7038370    0.200000
# 7038371    0.200000
# 6305154    1.000000
# 6305155    1.000000
# 300444     1.000000
#
# [10611522 rows x 6 columns]

# %%
# Assuming df_confidence is already loaded and contains the relevant data
grouped_df = df_sum_2.groupby('tool/menu')
processed_data = []

for group_name, group_df in tqdm(grouped_df, desc='processing merging'):
    # Drop duplicates based on the 'event' column within each group
    group_df = group_df.drop_duplicates(subset='event')
    processed_data.append(group_df)

# Concatenate all processed groups back into a single DataFrame
df_sum_3 = pd.concat(processed_data, ignore_index=True)
df_sum_3 = df_sum_3.reset_index(drop=True)
df_sum_3 = df_sum_3.sort_values(by= ['sup1_group_sum', 'tool/menu', 'sup2_sum'], ascending = False)
# Out:
# processing merging: 100%|█████████████████| 9155/9155 [00:01<00:00, 6730.31it/s]

# %%
# Ignore the pair which confidence <= 0.1
df_sum_3 = df_sum_3[df_sum_3['confidence'] >0.1]
df_sum_3
# Out:
#                                            tuple_commands  \
# 655940   [Tool: Reshape (-214), End Event: Reshape (279)]
# 655941     [Tool: Reshape (-214), End Event: Delete (58)]
# 655942       [Tool: Reshape (-214), End Event: Drag (75)]
# 655943    [Tool: Reshape (-214), End Event: Resize (146)]
# 655944  [Tool: Reshape (-214), End Event: Multiple Tra...
# ...                                                   ...
# 51460   [Menu: CExtMenu_TranslateLib -  (299) (0), End...
# 51461   [Menu: CExtMenu_TranslateLib -  (299) (0), End...
# 443366  [Menu: Shao Yi - (266) (0), End Event: The End...
# 443367  [Menu: Shao Yi - (266) (0), End Event: Mirror ...
# 28570   [Menu: Automate Scale -  (310) (0), End Event:...
#
#                                        tool/menu  \
# 655940                      Tool: Reshape (-214)
# 655941                      Tool: Reshape (-214)
# 655942                      Tool: Reshape (-214)
# 655943                      Tool: Reshape (-214)
# 655944                      Tool: Reshape (-214)
# ...                                          ...
# 51460   Menu: CExtMenu_TranslateLib -  (299) (0)
# 51461   Menu: CExtMenu_TranslateLib -  (299) (0)
# 443366                 Menu: Shao Yi - (266) (0)
# 443367                 Menu: Shao Yi - (266) (0)
# 28570          Menu: Automate Scale -  (310) (0)
#
#                                            event  sup1_group_sum  sup2_sum  \
# 655940                  End Event: Reshape (279)        29945982  21260047
# 655941                    End Event: Delete (58)        29945982   5156015
# 655942                      End Event: Drag (75)        29945982   4247671
# 655943                   End Event: Resize (146)        29945982   4002706
# 655944  End Event: Multiple Transformation (248)        29945982   3157471
# ...                                          ...             ...       ...
# 51460                 End Event: Exit Group (17)               5         1
# 51461         End Event: Update References (128)               5         1
# 443366             End Event: The End Event (-1)               3         3
# 443367          End Event: Mirror Duplicate (86)               3         3
# 28570         End Event: Update References (128)               1         1
#
#         confidence
# 655940    0.709947
# 655941    0.172177
# 655942    0.141844
# 655943    0.133664
# 655944    0.105439
# ...            ...
# 51460     0.200000
# 51461     0.200000
# 443366    1.000000
# 443367    1.000000
# 28570     1.000000
#
# [56981 rows x 6 columns]

# %%
# Ignore the effect of End Event which appear frequently and are not triggered by high level commands
df_sum_4 = df_sum_3[~df_sum_3['event'].isin(['End Event: Shape Pane Edit (89)', 'End Event: Delete (58)', 'End Event: Drag (75)', 'End Event: Set Active Layer (32)', 'End Event: Resize (146)'])]
df_sum_4
# Out:
#                                            tuple_commands  \
# 655940   [Tool: Reshape (-214), End Event: Reshape (279)]
# 655944  [Tool: Reshape (-214), End Event: Multiple Tra...
# 636155  [Tool: Move by Points (-352), End Event: Move ...
# 630595  [Tool: Line (-201), End Event: Create Line (166)]
# 412558  [Menu: Save -  (-5) (0), End Event: Duplicate ...
# ...                                                   ...
# 51460   [Menu: CExtMenu_TranslateLib -  (299) (0), End...
# 51461   [Menu: CExtMenu_TranslateLib -  (299) (0), End...
# 443366  [Menu: Shao Yi - (266) (0), End Event: The End...
# 443367  [Menu: Shao Yi - (266) (0), End Event: Mirror ...
# 28570   [Menu: Automate Scale -  (310) (0), End Event:...
#
#                                        tool/menu  \
# 655940                      Tool: Reshape (-214)
# 655944                      Tool: Reshape (-214)
# 636155               Tool: Move by Points (-352)
# 630595                         Tool: Line (-201)
# 412558                    Menu: Save -  (-5) (0)
# ...                                          ...
# 51460   Menu: CExtMenu_TranslateLib -  (299) (0)
# 51461   Menu: CExtMenu_TranslateLib -  (299) (0)
# 443366                 Menu: Shao Yi - (266) (0)
# 443367                 Menu: Shao Yi - (266) (0)
# 28570          Menu: Automate Scale -  (310) (0)
#
#                                            event  sup1_group_sum  sup2_sum  \
# 655940                  End Event: Reshape (279)        29945982  21260047
# 655944  End Event: Multiple Transformation (248)        29945982   3157471
# 636155                     End Event: Move (346)        21365110  21043027
# 630595              End Event: Create Line (166)        17893527  14422995
# 412558                End Event: Duplicate (206)        17072882   1873481
# ...                                          ...             ...       ...
# 51460                 End Event: Exit Group (17)               5         1
# 51461         End Event: Update References (128)               5         1
# 443366             End Event: The End Event (-1)               3         3
# 443367          End Event: Mirror Duplicate (86)               3         3
# 28570         End Event: Update References (128)               1         1
#
#         confidence
# 655940    0.709947
# 655944    0.105439
# 636155    0.984925
# 630595    0.806045
# 412558    0.109734
# ...            ...
# 51460     0.200000
# 51461     0.200000
# 443366    1.000000
# 443367    1.000000
# 28570     1.000000
#
# [35815 rows x 6 columns]

# %%
# Manually check again for the commands which appear frequently
df_sum_4.to_csv('/Users/confidence_test2.csv')

# %%
df_confidence = pd.read_csv('/Users/confidence_test2.csv')
df_confidence
# Out:
#        Unnamed: 0                                     tuple_commands  \
# 0          655940  ['Tool: Reshape (-214)' 'End Event: Reshape (2...
# 1          655944  ['Tool: Reshape (-214)' 'End Event: Multiple T...
# 2          636155  ['Tool: Move by Points (-352)' 'End Event: Mov...
# 3          630595  ['Tool: Line (-201)' 'End Event: Create Line (...
# 4          412558  ['Menu: Save -  (-5) (0)' 'End Event: Duplicat...
# ...           ...                                                ...
# 35810       51460  ['Menu: CExtMenu_TranslateLib -  (299) (0)' 'E...
# 35811       51461  ['Menu: CExtMenu_TranslateLib -  (299) (0)'\n ...
# 35812      443366  ['Menu: Shao Yi - (266) (0)' 'End Event: The E...
# 35813      443367  ['Menu: Shao Yi - (266) (0)' 'End Event: Mirro...
# 35814       28570  ['Menu: Automate Scale -  (310) (0)' 'End Even...
#
#                                       tool/menu  \
# 0                          Tool: Reshape (-214)
# 1                          Tool: Reshape (-214)
# 2                   Tool: Move by Points (-352)
# 3                             Tool: Line (-201)
# 4                        Menu: Save -  (-5) (0)
# ...                                         ...
# 35810  Menu: CExtMenu_TranslateLib -  (299) (0)
# 35811  Menu: CExtMenu_TranslateLib -  (299) (0)
# 35812                 Menu: Shao Yi - (266) (0)
# 35813                 Menu: Shao Yi - (266) (0)
# 35814         Menu: Automate Scale -  (310) (0)
#
#                                           event  sup1_group_sum  sup2_sum  \
# 0                      End Event: Reshape (279)        29945982  21260047
# 1      End Event: Multiple Transformation (248)        29945982   3157471
# 2                         End Event: Move (346)        21365110  21043027
# 3                  End Event: Create Line (166)        17893527  14422995
# 4                    End Event: Duplicate (206)        17072882   1873481
# ...                                         ...             ...       ...
# 35810                End Event: Exit Group (17)               5         1
# 35811        End Event: Update References (128)               5         1
# 35812             End Event: The End Event (-1)               3         3
# 35813          End Event: Mirror Duplicate (86)               3         3
# 35814        End Event: Update References (128)               1         1
#
#        confidence
# 0        0.709947
# 1        0.105439
# 2        0.984925
# 3        0.806045
# 4        0.109734
# ...           ...
# 35810    0.200000
# 35811    0.200000
# 35812    1.000000
# 35813    1.000000
# 35814    1.000000
#
# [35815 rows x 7 columns]

# %%
## For the commands which appear less than 1300 times, set confidence = 0.4 as threshold to determine whether they are related 

import pandas as pd
from tqdm import tqdm

# Assuming df_confidence is your DataFrame
grouped_df = df_confidence.groupby('tool/menu')
processed_data = []

for group_name, group_df in tqdm(grouped_df, desc='processing commands'):
    if group_df.iloc[0]['sup1_group_sum'] < 1300:
        group_df = group_df[group_df['confidence'] > 0.4]
        
    processed_data.append(group_df)

# Combine all processed groups back into a single DataFrame
result_df = pd.concat(processed_data, ignore_index=True)
result_df = result_df.drop(columns = 'Unnamed: 0')

result_df
# Out:
# processing commands: 100%|███████████████| 9061/9061 [00:00<00:00, 11491.53it/s]
#                                           tuple_commands  \
# 0      ['Menu:  -  (272) (0)' 'End Event: The Mantis ...
# 1      ['Menu:  -  (307) (0)' 'End Event: Create Data...
# 2      ['Menu:  Classes All On -  (244) (0)' 'End Eve...
# 3      ['Menu:  Show All Classes -  (344) (0)'\n 'End...
# 4      ['Menu:  Show All Objects -  (356) (0)'\n 'End...
# ...                                                  ...
# 11144  ['Tool: xplode -  nudge Y- (-102)' 'End Event:...
# 11145  ['Tool: xplode -  nudge Y- (-102)'\n 'End Even...
# 11146  ['Tool: xplode -  nudge Z+ (-102)'\n 'End Even...
# 11147  ['Tool: xplode -  nudge Z+ (-102)' 'End Event:...
# 11148  ['Tool: ~ScaleMaker V2 (-232)' 'End Event: Cre...
#
#                                   tool/menu  \
# 0                       Menu:  -  (272) (0)
# 1                       Menu:  -  (307) (0)
# 2        Menu:  Classes All On -  (244) (0)
# 3      Menu:  Show All Classes -  (344) (0)
# 4      Menu:  Show All Objects -  (356) (0)
# ...                                     ...
# 11144       Tool: xplode -  nudge Y- (-102)
# 11145       Tool: xplode -  nudge Y- (-102)
# 11146       Tool: xplode -  nudge Z+ (-102)
# 11147       Tool: xplode -  nudge Z+ (-102)
# 11148           Tool: ~ScaleMaker V2 (-232)
#
#                                              event  sup1_group_sum  sup2_sum  \
# 0                       End Event: The Mantis (-1)             123        56
# 1        End Event: Create Database Worksheet (19)              30        20
# 2                  End Event:  Classes All On (-1)              49        44
# 3                End Event:  Show All Classes (-1)             238       225
# 4                End Event:  Show All Objects (-1)              14        12
# ...                                            ...             ...       ...
# 11144           End Event: xplode -  nudge Y- (-1)              44        44
# 11145  End Event: Definieerxplode -  nudge Y- (-1)              44        30
# 11146    End Event: Define xplode -  nudge Z+ (-1)              17        17
# 11147           End Event: xplode -  nudge Y+ (-1)              17         9
# 11148               End Event: Create Object (166)              21        21
#
#        confidence
# 0        0.455285
# 1        0.666667
# 2        0.897959
# 3        0.945378
# 4        0.857143
# ...           ...
# 11144    1.000000
# 11145    0.681818
# 11146    1.000000
# 11147    0.529412
# 11148    1.000000
#
# [11149 rows x 6 columns]

# %%
result_df.to_csv('/data/command_pairs_collections.csv')

# %% [markdown]
# ## A manual refinement of the command_pairs_collections is further conducted within the software environment.
